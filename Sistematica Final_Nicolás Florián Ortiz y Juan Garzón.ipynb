# %% [markdown]
# # Backtesting sistematica

# %% [markdown]
# #### Hecho por: Nicolás Florián Ortiz y Juan Esteban Garzón Borda

# %% [markdown]
# Se importan las librerias necesarias para realizar el backtesting

# %%
# Preámbulo
import pandas as pd
import numpy as np

# %% [markdown]
# Para cada año se extrae la base de datos que contiene la información de las empresas pertenecientes

# %%
df_2015 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2015', header=[0, 1], index_col=0)
df_2016 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2016', header=[0, 1], index_col=0)
df_2017 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2017', header=[0, 1], index_col=0)
df_2018 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2018', header=[0, 1], index_col=0)
df_2019 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2019', header=[0, 1], index_col=0)
df_2020 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2020', header=[0, 1], index_col=0)
df_2021 = pd.read_excel('PRUEBA.xlsx', header=[0, 1], index_col=0)
df_2022 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2022', header=[0, 1], index_col=0)
df_2023 = pd.read_excel('Datos estrategia sistematica.xlsx', sheet_name='2023', header=[0, 1], index_col=0)

# %%
df_2021 = pd.read_excel('PRUEBA.xlsx', header=[0, 1], index_col=0)
df_2019 = pd.read_excel('PRUEBA_2019.xlsx', header=[0, 1], index_col=0)

# %% [markdown]
# Se define la función que realiza el backtesting para la base de datos

# %%
def Backtesting(capital_inicial, ventana_inicial, df):


    datos_por_empresa = {}

    # Iterar a través de las columnas del DataFrame original
    for col_idx in range(0, len(df.columns.levels[0]), 4):
        # Obtener el nombre de la empresa del índice de la columna
        nombre_empresa_original = df.columns[col_idx][0]
    
        # Extraer el segundo nombre de la empresa (el que está después de los dos puntos)
        if ':' in nombre_empresa_original:
            partes_nombre = nombre_empresa_original.split(':')
            nombre_empresa_nuevo = ':'.join(partes_nombre[1:]).strip()
        else:
            nombre_empresa_nuevo = nombre_empresa_original  # Si no hay dos puntos, mantener el nombre original
    
        # Seleccionar las columnas correspondientes para la empresa
        datos_empresa = df.iloc[:, col_idx:col_idx+4]
    
        # Convertir a números (asumiendo que estas columnas deben ser numéricas)
        datos_empresa = datos_empresa.apply(pd.to_numeric, errors='coerce')
    
        # Verificar si hay valores NA en algún lugar de los datos de la empresa
        if not datos_empresa.isnull().values.any() and 'PX_LAST' in datos_empresa.columns.get_level_values(1):
            # Almacenar en el diccionario con el nuevo nombre como clave
            datos_por_empresa[nombre_empresa_nuevo] = datos_empresa

 
    
    # Ahora, vamos a actualizar el diccionario con los nuevos nombres
    for nombre_original, datos_empresa in datos_por_empresa.items():
        # Extraer el segundo nombre de la empresa (el que está después de los dos puntos)
        if ':' in nombre_original:
            nombre_nuevo = nombre_original.split(':')[1].strip()
            # Actualizar el diccionario con el nuevo nombre como clave
            datos_por_empresa[nombre_nuevo] = datos_por_empresa.pop(nombre_original)


    # Crear un diccionario para almacenar los rendimientos por empresa
    rendimientos_por_empresa = {}
    
    # Calcular el rendimiento para cada empresa
    for empresa, datos_empresa in datos_por_empresa.items():
        # Obtener el precio en la posición 61 y el precio en la primera posición
        precio_posicion_61 = datos_empresa.iloc[ventana_inicial, 3]  # Tomar la cuarta columna sin importar el nombre
        precio_primera_posicion = datos_empresa.iloc[(ventana_inicial-60), 3]  # Tomar la cuarta columna sin importar el nombre
    
        # Calcular el rendimiento
        rendimiento = ((precio_posicion_61 / precio_primera_posicion) - 1) * 100
    
        # Almacenar el rendimiento en el diccionario
        rendimientos_por_empresa[empresa] = rendimiento
    
    # Crear un DataFrame a partir del diccionario de rendimientos
    df_rendimientos = pd.DataFrame(list(rendimientos_por_empresa.items()), columns=['Empresa', 'Rendimiento'])
    
    # Ordenar el DataFrame por rendimiento de mayor a menor
    df_rendimientos = df_rendimientos.sort_values(by='Rendimiento', ascending=False)
    
    # Tomar las primeras 15 posiciones como "Largo"
    df_largo = df_rendimientos.head(15)
    
    # Tomar las últimas 5 posiciones como "Corto"
    df_corto = df_rendimientos.tail(5)
    
    # Crear una nueva matriz para df_largo
    matriz_disminucion_pe_largo = pd.DataFrame(index=df_largo['Empresa'], columns=['Disminucion_PE'])

    # Iterar sobre las empresas en df_largo
    for idx, empresa in enumerate(df_largo['Empresa']):
        # Acceder a 'PE_RATIO' en el DataFrame de la empresa
        columna_pe_ratio = (empresa, 'PE_')
        
        # Obtener el PE_RATIO de la observación 61 en df_largo
        PE_RATIO_observacion_61_largo = datos_por_empresa[empresa][columna_pe_ratio].iloc[ventana_inicial]
    
        # Obtener el PE_RATIO de la primera observación para cada empresa en df_largo
        PE_RATIO_primera_observacion_largo = datos_por_empresa[empresa][columna_pe_ratio].iloc[(ventana_inicial-60)]
    
        # Marcar con 1 si hay disminución en PE_RATIO, de lo contrario, con 0
        matriz_disminucion_pe_largo.loc[empresa, 'Disminucion_PE'] = int(PE_RATIO_primera_observacion_largo > PE_RATIO_observacion_61_largo)
    
    # Para las cortas
    matriz_disminucion_pe_corto = pd.DataFrame(index=df_corto['Empresa'], columns=['Aumento_PE'])
    
    # Iterar sobre las empresas en df_largo
    for idx, empresa in enumerate(df_corto['Empresa']):
        # Acceder a 'PE_RATIO' en el DataFrame de la empresa
        columna_pe_ratio_c = (empresa, 'PE_')
        
        # Obtener el PE_RATIO de la observación 61 en df_largo
        PE_RATIO_observacion_61_corto = datos_por_empresa[empresa][columna_pe_ratio_c].iloc[ventana_inicial]
    
        # Obtener el PE_RATIO de la primera observación para cada empresa en df_largo
        PE_RATIO_primera_observacion_corto = datos_por_empresa[empresa][columna_pe_ratio_c].iloc[(ventana_inicial-1)]
    
        # Marcar con 1 si hay disminución en PE_RATIO, de lo contrario, con 0
        matriz_disminucion_pe_corto.loc[empresa, 'Aumento_PE'] = int(PE_RATIO_primera_observacion_largo < PE_RATIO_observacion_61_corto)
    
    # Crear matriz_MACO_largos
    matriz_MACO_largos = pd.DataFrame(index=df_largo['Empresa'], columns=['MACO'])
    
    # Iterar sobre las empresas en df_largo
    for empresa in df_largo['Empresa']:
        if empresa in datos_por_empresa:
            # Obtener los precios de cierre para la empresa
            precios_cierre = datos_por_empresa[empresa][empresa, 'PX_LAST']
    
            CP = 5
            LP = 30
            promedio_corto_plazo = precios_cierre.iloc[(ventana_inicial-CP):ventana_inicial].mean()
            promedio_largo_plazo = precios_cierre.iloc[(ventana_inicial-LP):ventana_inicial].mean()
    
            # Marcar con 1 si el promedio del corto plazo es mayor que el del largo plazo, de lo contrario, con 0
            matriz_MACO_largos.loc[empresa, 'MACO'] = int(promedio_corto_plazo > promedio_largo_plazo)
    
    # Para los cortos
    matriz_MACO_cortos = pd.DataFrame(index=df_corto['Empresa'], columns=['MACO'])
    
    for empresa in df_corto['Empresa']:
        if empresa in datos_por_empresa:
            pruebitas = datos_por_empresa[empresa].reset_index(drop = True)
            precios_cierre_c = datos_por_empresa[empresa][empresa].iloc[3]
            CP = 5
            LP = 30
            promedio_corto_plazo_c = precios_cierre_c.iloc[(ventana_inicial-CP):ventana_inicial].mean()
            promedio_largo_plazo_c = precios_cierre_c.iloc[(ventana_inicial-LP):ventana_inicial].mean()
    
            # Marcar con 1 si el promedio del corto plazo es mayor que el del largo plazo, de lo contrario, con 0
            matriz_MACO_cortos.loc[empresa, 'MACO'] = int(promedio_corto_plazo_c < promedio_largo_plazo_c)

    # Crear una nueva matriz para posiciones largas
    matriz_largo_ewma = pd.DataFrame(index=df_largo['Empresa'], columns=['Posicion'])
    
    # Factor de suavización para EWMA
    alpha = 2/(14+1)
    
    # Posición en la que estamos revisando la señal de compra
    posicion_actual = ventana_inicial
    
    # Aplicar EWMA a las empresas en df_largo y asignar señales de compra
    for empresa in df_largo['Empresa']:
        if empresa in datos_por_empresa:
            precios_cierre = datos_por_empresa[empresa].loc[:, (slice(None), 'PX_LAST')]  # Seleccionar la columna 'PX_LAST'
            ewma = precios_cierre.ewm(alpha=alpha, adjust=False).mean()
            
            # Comparar el valor en la posición actual con el valor de EWMA en la posición actual
            if precios_cierre.iloc[posicion_actual].max() > ewma.iloc[posicion_actual].max():
                matriz_largo_ewma.loc[empresa, 'Posicion'] = 1
            else:
                matriz_largo_ewma.loc[empresa, 'Posicion'] = 0
    
    matriz_corto_ewma = pd.DataFrame(index=df_corto['Empresa'], columns=['Posicion'])

    # Aplicar EWMA a las empresas en df_corto y asignar señales de venta
    for empresa in df_corto['Empresa']:
        if empresa in datos_por_empresa:
            precios_cierre = datos_por_empresa[empresa].loc[:, (slice(None), 'PX_LAST')]  # Seleccionar la columna 'PX_LAST'
            ewma = precios_cierre.ewm(alpha=alpha, adjust=False).mean()
            
            # Comparar el valor en la posición actual con el valor de EWMA en la posición actual
            if precios_cierre.iloc[posicion_actual].max() < ewma.iloc[posicion_actual].max():
                matriz_corto_ewma.loc[empresa, 'Posicion'] = 1
            else:
                matriz_corto_ewma.loc[empresa, 'Posicion'] = 0



    # Crear matrices para señales fuertes y débiles en largos y cortos
    matriz_fuerte_largo = pd.DataFrame(index=df_largo['Empresa'], columns=['Senal_Fuerte'])
    matriz_debil_largo = pd.DataFrame(index=df_largo['Empresa'], columns=['Senal_Debil'])
    matriz_fuerte_corto = pd.DataFrame(index=df_corto['Empresa'], columns=['Senal_Fuerte'])
    matriz_debil_corto = pd.DataFrame(index=df_corto['Empresa'], columns=['Senal_Debil'])

    # Iterar sobre las empresas en df_largo
    for empresa in df_largo['Empresa']:
        if empresa in datos_por_empresa:
            # Verificar condiciones para señal fuerte y débil en largos
            condicion_fuerte_largo = matriz_disminucion_pe_largo.loc[empresa, 'Disminucion_PE'] == 1 and matriz_MACO_largos.loc[empresa, 'MACO'] == 1
            condicion_debil_largo = matriz_disminucion_pe_largo.loc[empresa, 'Disminucion_PE'] == 1 or matriz_MACO_largos.loc[empresa, 'MACO'] == 1
    
            # Marcar con 1 si cumple la condición de señal fuerte, de lo contrario, con 0
            matriz_fuerte_largo.loc[empresa, 'Senal_Fuerte'] = int(condicion_fuerte_largo)
            # Marcar con 1 si cumple la condición de señal débil, de lo contrario, con 0
            matriz_debil_largo.loc[empresa, 'Senal_Debil'] = int(condicion_debil_largo)

        # Iterar sobre las empresas en df_corto
    for empresa in df_corto['Empresa']:
        if empresa in datos_por_empresa:
            # Verificar condiciones para señal fuerte y débil en cortos
            condicion_fuerte_corto = matriz_disminucion_pe_corto.loc[empresa, 'Aumento_PE'] == 1 and matriz_MACO_cortos.loc[empresa, 'MACO'] == 1
            condicion_debil_corto = matriz_disminucion_pe_corto.loc[empresa, 'Aumento_PE'] == 1 or matriz_MACO_cortos.loc[empresa, 'MACO'] == 1
    
            # Marcar con 1 si cumple la condición de señal fuerte, de lo contrario, con 0
            matriz_fuerte_corto.loc[empresa, 'Senal_Fuerte'] = int(condicion_fuerte_corto)
            # Marcar con 1 si cumple la condición de señal débil, de lo contrario, con 0
            matriz_debil_corto.loc[empresa, 'Senal_Debil'] = int(condicion_debil_corto)

    # Crear matrices para señales fuertes y débiles en largos y cortos
    matriz_fuerte_largo = pd.DataFrame(index=df_largo['Empresa'], columns=['Senal_Fuerte'])
    matriz_debil_largo = pd.DataFrame(index=df_largo['Empresa'], columns=['Senal_Debil'])
    matriz_fuerte_corto = pd.DataFrame(index=df_corto['Empresa'], columns=['Senal_Fuerte'])
    matriz_debil_corto = pd.DataFrame(index=df_corto['Empresa'], columns=['Senal_Debil'])
    
    # Iterar sobre las empresas en df_largo
    for empresa in df_largo['Empresa']:
        if empresa in datos_por_empresa:
            # Verificar condiciones para señal fuerte y débil en largos
            condicion_fuerte_largo = matriz_disminucion_pe_largo.loc[empresa, 'Disminucion_PE'] == 1 and matriz_MACO_largos.loc[empresa, 'MACO'] == 1
            condicion_debil_largo = matriz_disminucion_pe_largo.loc[empresa, 'Disminucion_PE'] == 1 or matriz_MACO_largos.loc[empresa, 'MACO'] == 1
    
            # Si cumple todas las condiciones, asignar a señal fuerte
            if condicion_fuerte_largo:
                matriz_fuerte_largo.loc[empresa, 'Senal_Fuerte'] = 1
            # Si cumple al menos una condición, asignar a señal débil
            elif condicion_debil_largo:
                matriz_debil_largo.loc[empresa, 'Senal_Debil'] = 1
    
    # Iterar sobre las empresas en df_corto
    for empresa in df_corto['Empresa']:
        if empresa in datos_por_empresa:
            # Verificar condicione para señal fuerte y débil en cortos
            condicion_fuerte_corto = matriz_disminucion_pe_corto.loc[empresa, 'Aumento_PE'] == 1 and matriz_MACO_cortos.loc[empresa, 'MACO'] == 1
            condicion_debil_corto = matriz_disminucion_pe_corto.loc[empresa, 'Aumento_PE'] == 1 or matriz_MACO_cortos.loc[empresa, 'MACO'] == 1
    
            # Si cumple todas las condiciones, asignar a señal fuerte
            if condicion_fuerte_corto:
                matriz_fuerte_corto.loc[empresa, 'Senal_Fuerte'] = 1
            # Si cumple al menos una condición, asignar a señal débil
            elif condicion_debil_corto:
                matriz_debil_corto.loc[empresa, 'Senal_Debil'] = 1
    
    
    # Combina las empresas de señal débil para largos y cortos en una sola matriz
    matriz_debil_total = pd.concat([matriz_debil_largo, matriz_debil_corto])

    # Asigna pesos usando la metodología de "volatility parity"
    # Calcula la volatilidad de cada empresa
    volatilidades_debil = {}
    for empresa in matriz_debil_total.index:
        if empresa in datos_por_empresa:
            # Obtén la última columna de la matriz de datos_por_empresa para evitar el KeyError
            columna_px_last = datos_por_empresa[empresa].columns[-1]
            
            # Calcula el rendimiento logarítmico diario directamente desde la última columna
            rendimientos = np.log(datos_por_empresa[empresa][columna_px_last] / datos_por_empresa[empresa][columna_px_last].shift(1))
            
            # Calcula la volatilidad como la desviación estándar del rendimiento logarítmico
            volatilidad = rendimientos.std()

            # Almacena la volatilidad en el diccionario
            volatilidades_debil[empresa] = volatilidad

    # Normaliza las volatilidades
    total_volatilidad_debil = sum(volatilidades_debil.values())
    volatilidades_normalizadas_debil = {empresa: vol / total_volatilidad_debil for empresa, vol in volatilidades_debil.items()}
    
    # Crea un DataFrame para almacenar los nombres de las empresas y los pesos asignados
    df_pesos_debil = pd.DataFrame(list(volatilidades_normalizadas_debil.items()), columns=['Empresa', 'Peso'])

    # Definir las matrices de señales fuertes para largos y cortos
    matriz_fuerte_total = pd.concat([matriz_fuerte_largo.dropna(), matriz_fuerte_corto.dropna()])
    
    # Filtrar empresas con señales fuertes
    empresas_fuertes = matriz_fuerte_total.index
    
    # Crear un DataFrame para almacenar las volatilidades y los precios de cierre de las empresas fuertes
    df_vol_precios = pd.DataFrame(index=empresas_fuertes, columns=['Volatilidad', 'Precios'])
    
    # Calcular volatilidad y asignar precios
    for empresa in empresas_fuertes:
        if empresa in datos_por_empresa:
            # Obtener la columna de precios (cuarta columna)
            precios_cierre = datos_por_empresa[empresa].iloc[0:ventana_inicial, 3]
    
            # Calcular rendimientos diarios negativos
            rendimientos_negativos = np.log(precios_cierre / precios_cierre.shift(1))
            rendimientos_negativos = rendimientos_negativos[rendimientos_negativos < 0]
    
            # Calcular volatilidad como desviación estándar de rendimientos negativos
            volatilidad = rendimientos_negativos.std()
    
            # Almacenar en el DataFrame
            df_vol_precios.loc[empresa, 'Volatilidad'] = volatilidad
            df_vol_precios.loc[empresa, 'Precios'] = precios_cierre.tolist()  # Almacenar la serie completa

    # Ordenar empresas por volatilidad de mayor a menor
    df_vol_precios = df_vol_precios.sort_values(by='Volatilidad', ascending=False)
    
    # Asignar valores objetivos según posición en la lista ordenada
    n_empresas = len(df_vol_precios)
    df_vol_precios['Valor_Objetivo'] = np.arange(0.05, 0.05 * (n_empresas + 1), 0.05)[:n_empresas]

    
    # Calcular valor operativo para cada empresa
    df_vol_precios['Valor_Operativo'] = df_vol_precios['Valor_Objetivo'] / df_vol_precios['Volatilidad']
    
    # Calcular total valor operativo
    total_valor_operativo = df_vol_precios['Valor_Operativo'].sum()
    
    # Calcular ponderaciones
    df_vol_precios['Ponderacion'] = df_vol_precios['Valor_Operativo'] / total_valor_operativo
    
    # Crear DataFrame final con nombre de la empresa y ponderación
    df_ponderaciones = df_vol_precios[['Ponderacion']].reset_index()

    # Calcular el capital destinado para las señales fuertes (35% del capital inicial)
    capital_fuerte = capital_inicial * 0.35
    
    # Calcular el capital destinado para las señales débiles (65% del capital inicial)
    capital_debil = capital_inicial * 0.65
    
    # Crear una columna en df_ponderaciones para almacenar el capital invertido
    df_ponderaciones['Capital_Invertido'] = df_ponderaciones['Ponderacion'] * capital_fuerte
    
    # Crear una columna en df_pesos_debil para almacenar el capital invertido
    df_pesos_debil['Capital_Invertido'] = df_pesos_debil['Peso'] * capital_debil
    
    # Crear una nueva columna en df_ponderaciones para almacenar el rendimiento
    df_ponderaciones['Rendimiento'] = 0.0
    
    # Crear una nueva columna en df_pesos_debil para almacenar el rendimiento
    df_pesos_debil['Rendimiento'] = 0.0

    # Iterar sobre las empresas en df_ponderaciones
    for idx, row in df_ponderaciones.iterrows():
        empresa = row['Empresa']
        capital_invertido = row['Capital_Invertido']
        
        # Verificar si la empresa es larga en la matriz de señales fuertes
        if empresa in matriz_fuerte_largo.index:
            # Calcular el rendimiento como precio final / precio inicial - 1
            rendimiento = (datos_por_empresa[empresa].iloc[(ventana_inicial+5), 3] / datos_por_empresa[empresa].iloc[ventana_inicial, 3]) - 1
        elif empresa in matriz_fuerte_corto.index:
            # Calcular el rendimiento como precio inicial / precio final - 1 para cortos
            rendimiento = (datos_por_empresa[empresa].iloc[ventana_inicial, 3] / datos_por_empresa[empresa].iloc[(ventana_inicial + 5), 3]) - 1
        
        # Almacenar el rendimiento en la columna correspondiente
        df_ponderaciones.loc[idx, 'Rendimiento'] = rendimiento


    # Iterar sobre las empresas en df_pesos_debil
    for idx, row in df_pesos_debil.iterrows():
        empresa = row['Empresa']
        capital_invertido = row['Capital_Invertido']
        
        # Verificar si la empresa es larga en la matriz de señales débiles
        if empresa in matriz_debil_largo.index:
            # Calcular el rendimiento como precio final / precio inicial - 1
            rendimiento = (datos_por_empresa[empresa].iloc[(ventana_inicial + 5), 3] / datos_por_empresa[empresa].iloc[ventana_inicial, 3]) - 1
        elif empresa in matriz_debil_corto.index:
            # Calcular el rendimiento como precio inicial / precio final - 1 para cortos
            rendimiento = (datos_por_empresa[empresa].iloc[ventana_inicial, 3] / datos_por_empresa[empresa].iloc[(ventana_inicial + 5), 3]) - 1
        
        # Almacenar el rendimiento en la columna correspondiente
        df_pesos_debil.loc[idx, 'Rendimiento'] = rendimiento

    # Sumar los rendimientos para obtener el rendimiento total
    rendimiento_total_fuerte = df_ponderaciones['Rendimiento'].sum()
    rendimiento_total_debil = df_pesos_debil['Rendimiento'].sum()
    
    # Calcular el dinero final
    dinero_final_fuerte = capital_fuerte * (1 + rendimiento_total_fuerte)
    dinero_final_debil = capital_debil * (1 + rendimiento_total_debil)
    
    # Calcular el dinero total final
    dinero_total_final = dinero_final_fuerte + dinero_final_debil
    
    # Calcular la diferencia con el capital inicial
    diferencia = dinero_total_final - capital_inicial

    
    # Mostrar los resultados
    print("Dinero inicial: $", capital_inicial)
    print("Dinero Final Fuerte: $", dinero_final_fuerte)
    print("Dinero Final Débil: $", dinero_final_debil)
    print("Dinero Total Final: $", dinero_total_final)
    print("Diferencia con el Capital Inicial: $", diferencia)
    print("RDTO:" , (dinero_total_final/capital_inicial -1))

# %% [markdown]
# Para el 2015

# %%
for i in range(60, 260, 5):
    Backtesting(1000000, i , df_2015)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 377999.99999999994
# Dinero Final Débil: $ 966344.9739268114
# Dinero Total Final: $ 1344344.9739268112
# Diferencia con el Capital Inicial: $ 344344.97392681125
# RDTO: 0.3443449739268112
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 768413.5666286141
# Dinero Total Final: $ 1118413.566628614
# Diferencia con el Capital Inicial: $ 118413.56662861397
# RDTO: 0.11841356662861391
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ -89077.35197877488
# Dinero Total Final: $ 260922.64802122512
# Diferencia con el Capital Inicial: $ -739077.3519787749
# RDTO: -0.7390773519787749
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 742681.3195038651
# Dinero Total Final: $ 1092681.3195038652
# Diferencia con el Capital Inicial: $ 92681.3195038652
# RDTO: 0.09268131950386516
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 440084.9714684849
# Dinero Total Final: $ 790084.971468485
# Diferencia con el Capital Inicial: $ -209915.02853151504
# RDTO: -0.209915028531515
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650436.658820121
# Dinero Total Final: $ 1000436.658820121
# Diferencia con el Capital Inicial: $ 436.658820120967
# RDTO: 0.0004366588201210053
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1363474.520711847
# Dinero Total Final: $ 1713474.520711847
# Diferencia con el Capital Inicial: $ 713474.5207118471
# RDTO: 0.7134745207118471
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 708948.6156671941
# Dinero Total Final: $ 1058948.6156671941
# Diferencia con el Capital Inicial: $ 58948.61566719413
# RDTO: 0.058948615667194115
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 448813.2907002138
# Dinero Total Final: $ 798813.2907002138
# Diferencia con el Capital Inicial: $ -201186.70929978625
# RDTO: -0.20118670929978621
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 910964.6582474993
# Dinero Total Final: $ 1260964.6582474993
# Diferencia con el Capital Inicial: $ 260964.65824749926
# RDTO: 0.26096465824749937
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 391930.2870533099
# Dinero Final Débil: $ 482909.0143038285
# Dinero Total Final: $ 874839.3013571384
# Diferencia con el Capital Inicial: $ -125160.69864286156
# RDTO: -0.1251606986428616
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 325035.4274917336
# Dinero Final Débil: $ 588389.7919728798
# Dinero Total Final: $ 913425.2194646134
# Diferencia con el Capital Inicial: $ -86574.78053538664
# RDTO: -0.0865747805353867
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 736668.9754368287
# Dinero Total Final: $ 1086668.9754368286
# Diferencia con el Capital Inicial: $ 86668.97543682856
# RDTO: 0.08666897543682861
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 740873.3513592376
# Dinero Total Final: $ 1090873.3513592375
# Diferencia con el Capital Inicial: $ 90873.35135923745
# RDTO: 0.09087335135923746
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 663845.3219795693
# Dinero Total Final: $ 1013845.3219795693
# Diferencia con el Capital Inicial: $ 13845.321979569271
# RDTO: 0.013845321979569336
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 332999.2289899768
# Dinero Final Débil: $ 681834.6753152974
# Dinero Total Final: $ 1014833.9043052742
# Diferencia con el Capital Inicial: $ 14833.904305274249
# RDTO: 0.014833904305274315
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 636732.2643254929
# Dinero Total Final: $ 986732.2643254929
# Diferencia con el Capital Inicial: $ -13267.735674507101
# RDTO: -0.01326773567450712
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ -16261.661057270694
# Dinero Total Final: $ 333738.3389427293
# Diferencia con el Capital Inicial: $ -666261.6610572707
# RDTO: -0.6662616610572707
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 600168.416091655
# Dinero Total Final: $ 950168.416091655
# Diferencia con el Capital Inicial: $ -49831.58390834497
# RDTO: -0.04983158390834497
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 968379.9106034724
# Dinero Total Final: $ 1318379.9106034725
# Diferencia con el Capital Inicial: $ 318379.9106034725
# RDTO: 0.3183799106034726
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 724066.507401377
# Dinero Total Final: $ 1074066.507401377
# Diferencia con el Capital Inicial: $ 74066.50740137696
# RDTO: 0.07406650740137688
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 330079.41760423564
# Dinero Final Débil: $ 699287.2065776573
# Dinero Total Final: $ 1029366.624181893
# Diferencia con el Capital Inicial: $ 29366.624181892956
# RDTO: 0.029366624181893064
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 652558.1049578058
# Dinero Total Final: $ 1002558.1049578058
# Diferencia con el Capital Inicial: $ 2558.10495780583
# RDTO: 0.00255810495780584
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 528369.9665260859
# Dinero Total Final: $ 878369.9665260859
# Diferencia con el Capital Inicial: $ -121630.03347391414
# RDTO: -0.1216300334739141
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 313418.5315547922
# Dinero Final Débil: $ 636677.4055132708
# Dinero Total Final: $ 950095.937068063
# Diferencia con el Capital Inicial: $ -49904.06293193705
# RDTO: -0.049904062931937054
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 831626.2467775168
# Dinero Total Final: $ 1181626.2467775168
# Diferencia con el Capital Inicial: $ 181626.2467775168
# RDTO: 0.1816262467775167
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 359300.6993006993
# Dinero Final Débil: $ 482323.33323401574
# Dinero Total Final: $ 841624.032534715
# Diferencia con el Capital Inicial: $ -158375.96746528498
# RDTO: -0.15837596746528493
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 347377.3841961853
# Dinero Final Débil: $ 972089.4011659987
# Dinero Total Final: $ 1319466.785362184
# Diferencia con el Capital Inicial: $ 319466.78536218405
# RDTO: 0.319466785362184
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 351921.7570350034
# Dinero Final Débil: $ 702574.11513846
# Dinero Total Final: $ 1054495.8721734635
# Diferencia con el Capital Inicial: $ 54495.87217346346
# RDTO: 0.05449587217346341
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 328976.10921501706
# Dinero Final Débil: $ 662450.6664746751
# Dinero Total Final: $ 991426.7756896921
# Diferencia con el Capital Inicial: $ -8573.22431030788
# RDTO: -0.008573224310307825
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 662135.9790632806
# Dinero Total Final: $ 1012135.9790632806
# Diferencia con el Capital Inicial: $ 12135.979063280625
# RDTO: 0.012135979063280677

# %% [markdown]
# Para el 2016

# %%
for i in range(60, 255, 5):
    Backtesting(1000000, i , df_2016)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 707235.7390465525
# Dinero Total Final: $ 1057235.7390465525
# Diferencia con el Capital Inicial: $ 57235.73904655245
# RDTO: 0.05723573904655255
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 354751.1312217195
# Dinero Final Débil: $ 816077.5755435039
# Dinero Total Final: $ 1170828.7067652233
# Diferencia con el Capital Inicial: $ 170828.7067652233
# RDTO: 0.17082870676522321
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 382812.5
# Dinero Final Débil: $ 876451.7613474169
# Dinero Total Final: $ 1259264.2613474168
# Diferencia con el Capital Inicial: $ 259264.2613474168
# RDTO: 0.25926426134741676
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 373142.5004458712
# Dinero Final Débil: $ 669879.3066182988
# Dinero Total Final: $ 1043021.80706417
# Diferencia con el Capital Inicial: $ 43021.80706417002
# RDTO: 0.043021807064169915
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 361612.13706962444
# Dinero Final Débil: $ 724921.519899112
# Dinero Total Final: $ 1086533.6569687366
# Diferencia con el Capital Inicial: $ 86533.65696873656
# RDTO: 0.0865336569687365
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 381583.7937384899
# Dinero Final Débil: $ 131487.47181559703
# Dinero Total Final: $ 513071.26555408695
# Diferencia con el Capital Inicial: $ -486928.73444591305
# RDTO: -0.486928734445913
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 336993.24324324325
# Dinero Final Débil: $ 683168.0307599733
# Dinero Total Final: $ 1020161.2740032165
# Diferencia con el Capital Inicial: $ 20161.27400321653
# RDTO: 0.020161274003216434
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 354912.2807017544
# Dinero Final Débil: $ 671211.8234408668
# Dinero Total Final: $ 1026124.1041426212
# Diferencia con el Capital Inicial: $ 26124.10414262116
# RDTO: 0.02612410414262123
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 348788.9273356401
# Dinero Final Débil: $ 929200.5949047559
# Dinero Total Final: $ 1277989.5222403961
# Diferencia con el Capital Inicial: $ 277989.5222403961
# RDTO: 0.2779895222403961
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 424061.87229703425
# Dinero Final Débil: $ 1204286.419065316
# Dinero Total Final: $ 1628348.2913623503
# Diferencia con el Capital Inicial: $ 628348.2913623503
# RDTO: 0.6283482913623504
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 301043.1484115695
# Dinero Final Débil: $ 493484.51529296936
# Dinero Total Final: $ 794527.6637045388
# Diferencia con el Capital Inicial: $ -205472.33629546117
# RDTO: -0.20547233629546113
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 343284.4631721786
# Dinero Final Débil: $ 871054.5666602792
# Dinero Total Final: $ 1214339.0298324577
# Diferencia con el Capital Inicial: $ 214339.02983245766
# RDTO: 0.21433902983245767
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 323539.5189003436
# Dinero Final Débil: $ 468689.6048777154
# Dinero Total Final: $ 792229.123778059
# Diferencia con el Capital Inicial: $ -207770.87622194097
# RDTO: -0.20777087622194101
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1001517.0713796702
# Dinero Total Final: $ 1351517.0713796702
# Diferencia con el Capital Inicial: $ 351517.0713796702
# RDTO: 0.35151707137967025
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 635294.0215411731
# Dinero Total Final: $ 985294.0215411731
# Diferencia con el Capital Inicial: $ -14705.978458826896
# RDTO: -0.01470597845882693
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 373260.37618355564
# Dinero Final Débil: $ 562313.4257233185
# Dinero Total Final: $ 935573.8019068742
# Diferencia con el Capital Inicial: $ -64426.19809312583
# RDTO: -0.06442619809312577
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 324866.5196416964
# Dinero Final Débil: $ 573516.5533105159
# Dinero Total Final: $ 898383.0729522123
# Diferencia con el Capital Inicial: $ -101616.9270477877
# RDTO: -0.10161692704778769
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 340989.29641065875
# Dinero Final Débil: $ 859593.095929307
# Dinero Total Final: $ 1200582.3923399658
# Diferencia con el Capital Inicial: $ 200582.3923399658
# RDTO: 0.2005823923399659
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 399167.53381893865
# Dinero Final Débil: $ 838701.408581684
# Dinero Total Final: $ 1237868.9424006226
# Diferencia con el Capital Inicial: $ 237868.94240062265
# RDTO: 0.23786894240062262
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 343932.4817518248
# Dinero Final Débil: $ 978878.0032565726
# Dinero Total Final: $ 1322810.4850083974
# Diferencia con el Capital Inicial: $ 322810.4850083974
# RDTO: 0.32281048500839726
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 343317.75700934575
# Dinero Final Débil: $ 1119582.6556784722
# Dinero Total Final: $ 1462900.412687818
# Diferencia con el Capital Inicial: $ 462900.41268781805
# RDTO: 0.462900412687818
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 781008.3231292989
# Dinero Total Final: $ 1131008.3231292989
# Diferencia con el Capital Inicial: $ 131008.32312929886
# RDTO: 0.1310083231292989
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 346218.0746561886
# Dinero Final Débil: $ 913105.290234599
# Dinero Total Final: $ 1259323.3648907878
# Diferencia con el Capital Inicial: $ 259323.36489078775
# RDTO: 0.2593233648907878
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 465201.3071486048
# Dinero Total Final: $ 815201.3071486049
# Diferencia con el Capital Inicial: $ -184798.6928513951
# RDTO: -0.18479869285139516
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 662885.921718856
# Dinero Total Final: $ 1012885.921718856
# Diferencia con el Capital Inicial: $ 12885.92171885597
# RDTO: 0.012885921718855942
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 471087.31106687355
# Dinero Total Final: $ 821087.3110668736
# Diferencia con el Capital Inicial: $ -178912.6889331264
# RDTO: -0.1789126889331264
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 328904.1095890411
# Dinero Final Débil: $ 424933.02844397153
# Dinero Total Final: $ 753837.1380330126
# Diferencia con el Capital Inicial: $ -246162.86196698737
# RDTO: -0.24616286196698733
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 359863.9455782313
# Dinero Final Débil: $ 637420.5650136324
# Dinero Total Final: $ 997284.5105918637
# Diferencia con el Capital Inicial: $ -2715.4894081363454
# RDTO: -0.0027154894081363734
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 300378.07183364837
# Dinero Final Débil: $ 385051.00461190054
# Dinero Total Final: $ 685429.0764455489
# Diferencia con el Capital Inicial: $ -314570.9235544511
# RDTO: -0.31457092355445104
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 351217.27988284826
# Dinero Final Débil: $ 653391.3303533097
# Dinero Total Final: $ 1004608.610236158
# Diferencia con el Capital Inicial: $ 4608.610236158012
# RDTO: 0.004608610236157995
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 155791.29085738293
# Dinero Total Final: $ 505791.29085738293
# Diferencia con el Capital Inicial: $ -494208.70914261707
# RDTO: -0.49420870914261705
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 355716.8784029038
# Dinero Final Débil: $ 1402205.0068900685
# Dinero Total Final: $ 1757921.8852929724
# Diferencia con el Capital Inicial: $ 757921.8852929724
# RDTO: 0.7579218852929723
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 995527.6843870564
# Dinero Total Final: $ 1345527.6843870564
# Diferencia con el Capital Inicial: $ 345527.6843870564
# RDTO: 0.3455276843870565
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 793792.3918184129
# Dinero Total Final: $ 1143792.391818413
# Diferencia con el Capital Inicial: $ 143792.39181841305
# RDTO: 0.14379239181841297
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 725890.6561148557
# Dinero Total Final: $ 1075890.6561148558
# Diferencia con el Capital Inicial: $ 75890.65611485578
# RDTO: 0.07589065611485579
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 787610.4994733741
# Dinero Total Final: $ 1137610.499473374
# Diferencia con el Capital Inicial: $ 137610.4994733741
# RDTO: 0.137610499473374
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 351347.8818998716
# Dinero Final Débil: $ 746413.5065874945
# Dinero Total Final: $ 1097761.388487366
# Diferencia con el Capital Inicial: $ 97761.38848736603
# RDTO: 0.09776138848736604
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 544866.5963090871
# Dinero Total Final: $ 894866.5963090871
# Diferencia con el Capital Inicial: $ -105133.40369091288
# RDTO: -0.10513340369091284
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 618848.3377685327
# Dinero Total Final: $ 968848.3377685327
# Diferencia con el Capital Inicial: $ -31151.662231467315
# RDTO: -0.03115166223146737

# %% [markdown]
# Para el 2017

# %%
for i in range(60, 255, 5):
    Backtesting(1000000, i , df_2017)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 758159.0568720237
# Dinero Total Final: $ 1108159.0568720237
# Diferencia con el Capital Inicial: $ 108159.05687202374
# RDTO: 0.10815905687202365
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 318701.79907169146
# Dinero Final Débil: $ 813023.6817255478
# Dinero Total Final: $ 1131725.480797239
# Diferencia con el Capital Inicial: $ 131725.4807972391
# RDTO: 0.131725480797239
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350180.97970194294
# Dinero Final Débil: $ 588710.1483555547
# Dinero Total Final: $ 938891.1280574976
# Diferencia con el Capital Inicial: $ -61108.87194250245
# RDTO: -0.061108871942502474
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 388186.4316433969
# Dinero Final Débil: $ 980885.4207513185
# Dinero Total Final: $ 1369071.8523947154
# Diferencia con el Capital Inicial: $ 369071.8523947154
# RDTO: 0.3690718523947154
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 396029.4748088245
# Dinero Final Débil: $ 1145414.2394102714
# Dinero Total Final: $ 1541443.714219096
# Diferencia con el Capital Inicial: $ 541443.7142190959
# RDTO: 0.541443714219096
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 379815.8813015973
# Dinero Final Débil: $ 916557.7515484149
# Dinero Total Final: $ 1296373.6328500123
# Diferencia con el Capital Inicial: $ 296373.6328500123
# RDTO: 0.29637363285001217
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 385586.1657724465
# Dinero Final Débil: $ 852293.327831168
# Dinero Total Final: $ 1237879.4936036144
# Diferencia con el Capital Inicial: $ 237879.4936036144
# RDTO: 0.23787949360361438
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 346795.22841413034
# Dinero Final Débil: $ 590089.1232960995
# Dinero Total Final: $ 936884.3517102299
# Diferencia con el Capital Inicial: $ -63115.64828977012
# RDTO: -0.06311564828977012
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 348501.4913638034
# Dinero Final Débil: $ 775165.2988473306
# Dinero Total Final: $ 1123666.7902111341
# Diferencia con el Capital Inicial: $ 123666.79021113412
# RDTO: 0.12366679021113414
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 329134.7241868287
# Dinero Final Débil: $ 734970.464577531
# Dinero Total Final: $ 1064105.1887643598
# Diferencia con el Capital Inicial: $ 64105.1887643598
# RDTO: 0.06410518876435978
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 346311.81511101977
# Dinero Final Débil: $ 483980.63994710526
# Dinero Total Final: $ 830292.4550581251
# Diferencia con el Capital Inicial: $ -169707.54494187492
# RDTO: -0.1697075449418749
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 315372.6708074534
# Dinero Final Débil: $ 683701.5895202528
# Dinero Total Final: $ 999074.2603277061
# Diferencia con el Capital Inicial: $ -925.7396722938865
# RDTO: -0.0009257396722939237
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 354137.6912378303
# Dinero Final Débil: $ 626374.655906838
# Dinero Total Final: $ 980512.3471446683
# Diferencia con el Capital Inicial: $ -19487.65285533166
# RDTO: -0.019487652855331605
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 785799.517743041
# Dinero Total Final: $ 1135799.517743041
# Diferencia con el Capital Inicial: $ 135799.51774304104
# RDTO: 0.1357995177430411
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 359459.45945945947
# Dinero Final Débil: $ 821902.1173779765
# Dinero Total Final: $ 1181361.576837436
# Diferencia con el Capital Inicial: $ 181361.57683743606
# RDTO: 0.18136157683743614
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350708.50202429155
# Dinero Final Débil: $ 678237.936266298
# Dinero Total Final: $ 1028946.4382905896
# Diferencia con el Capital Inicial: $ 28946.438290589605
# RDTO: 0.028946438290589516
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 358172.1900500438
# Dinero Final Débil: $ 596374.7383540861
# Dinero Total Final: $ 954546.9284041298
# Diferencia con el Capital Inicial: $ -45453.07159587019
# RDTO: -0.0454530715958702
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 332914.6931774375
# Dinero Final Débil: $ 298301.87741369416
# Dinero Total Final: $ 631216.5705911317
# Diferencia con el Capital Inicial: $ -368783.4294088683
# RDTO: -0.3687834294088683
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 399249.1423782924
# Dinero Final Débil: $ 874505.2383378482
# Dinero Total Final: $ 1273754.3807161406
# Diferencia con el Capital Inicial: $ 273754.3807161406
# RDTO: 0.27375438071614067
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 335160.5476356906
# Dinero Final Débil: $ 175998.5034145476
# Dinero Total Final: $ 511159.0510502382
# Diferencia con el Capital Inicial: $ -488840.9489497618
# RDTO: -0.4888409489497618
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 368448.7951807229
# Dinero Final Débil: $ 700535.7042672164
# Dinero Total Final: $ 1068984.4994479392
# Diferencia con el Capital Inicial: $ 68984.49944793922
# RDTO: 0.06898449944793916
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 641228.9226561849
# Dinero Total Final: $ 991228.9226561849
# Diferencia con el Capital Inicial: $ -8771.077343815123
# RDTO: -0.008771077343815104
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 378990.74149053905
# Dinero Final Débil: $ 781466.5945663357
# Dinero Total Final: $ 1160457.3360568746
# Diferencia con el Capital Inicial: $ 160457.3360568746
# RDTO: 0.16045733605687462
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 387993.58390654996
# Dinero Final Débil: $ 798087.1067946323
# Dinero Total Final: $ 1186080.6907011822
# Diferencia con el Capital Inicial: $ 186080.69070118223
# RDTO: 0.18608069070118227
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 358189.9525419013
# Dinero Final Débil: $ 864926.9870752164
# Dinero Total Final: $ 1223116.9396171176
# Diferencia con el Capital Inicial: $ 223116.93961711763
# RDTO: 0.22311693961711754
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 354116.2903065924
# Dinero Final Débil: $ 581377.7587749847
# Dinero Total Final: $ 935494.0490815772
# Diferencia con el Capital Inicial: $ -64505.95091842278
# RDTO: -0.06450595091842282
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1084586.2816527125
# Dinero Total Final: $ 1434586.2816527125
# Diferencia con el Capital Inicial: $ 434586.2816527125
# RDTO: 0.4345862816527124
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 595500.7683793455
# Dinero Total Final: $ 945500.7683793455
# Diferencia con el Capital Inicial: $ -54499.231620654464
# RDTO: -0.05449923162065451
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 377759.47277473396
# Dinero Final Débil: $ 730427.4338578685
# Dinero Total Final: $ 1108186.9066326024
# Diferencia con el Capital Inicial: $ 108186.90663260245
# RDTO: 0.10818690663260244
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 353992.92752490024
# Dinero Final Débil: $ 507149.0887003111
# Dinero Total Final: $ 861142.0162252113
# Diferencia con el Capital Inicial: $ -138857.98377478868
# RDTO: -0.13885798377478864
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 353868.1392150074
# Dinero Final Débil: $ 635951.1243714623
# Dinero Total Final: $ 989819.2635864697
# Diferencia con el Capital Inicial: $ -10180.736413530307
# RDTO: -0.010180736413530345
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 396228.7371323032
# Dinero Final Débil: $ 508280.3569193727
# Dinero Total Final: $ 904509.0940516759
# Diferencia con el Capital Inicial: $ -95490.90594832413
# RDTO: -0.0954909059483241
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 346532.71087969386
# Dinero Final Débil: $ 851232.4893480852
# Dinero Total Final: $ 1197765.200227779
# Diferencia con el Capital Inicial: $ 197765.2002277791
# RDTO: 0.19776520022777921
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 402084.8188516177
# Dinero Final Débil: $ 1194454.8716893278
# Dinero Total Final: $ 1596539.6905409454
# Diferencia con el Capital Inicial: $ 596539.6905409454
# RDTO: 0.5965396905409455
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 358439.60153732036
# Dinero Final Débil: $ 739699.5991002019
# Dinero Total Final: $ 1098139.2006375222
# Diferencia con el Capital Inicial: $ 98139.20063752215
# RDTO: 0.09813920063752213
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 348345.27766335587
# Dinero Final Débil: $ 251682.40613014152
# Dinero Total Final: $ 600027.6837934974
# Diferencia con el Capital Inicial: $ -399972.3162065026
# RDTO: -0.39997231620650264
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 351864.6116151248
# Dinero Final Débil: $ 757416.9323102472
# Dinero Total Final: $ 1109281.543925372
# Diferencia con el Capital Inicial: $ 109281.54392537195
# RDTO: 0.10928154392537204
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 455695.88022371946
# Dinero Final Débil: $ 1080949.267420924
# Dinero Total Final: $ 1536645.1476446434
# Diferencia con el Capital Inicial: $ 536645.1476446434
# RDTO: 0.5366451476446434
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 376057.60621971474
# Dinero Final Débil: $ 508900.3300307574
# Dinero Total Final: $ 884957.9362504722
# Diferencia con el Capital Inicial: $ -115042.06374952779
# RDTO: -0.11504206374952775

# %% [markdown]
# Para el 2018

# %%
for i in range(60, 260, 5):
    Backtesting(1000000, i , df_2018)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 368991.0979228487
# Dinero Final Débil: $ 721953.6206348685
# Dinero Total Final: $ 1090944.7185577173
# Diferencia con el Capital Inicial: $ 90944.71855771728
# RDTO: 0.09094471855771724
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 403466.9365206114
# Dinero Final Débil: $ 785402.5545935306
# Dinero Total Final: $ 1188869.491114142
# Diferencia con el Capital Inicial: $ 188869.49111414189
# RDTO: 0.18886949111414197
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 355729.53736654803
# Dinero Final Débil: $ 459779.63769790804
# Dinero Total Final: $ 815509.1750644561
# Diferencia con el Capital Inicial: $ -184490.82493554393
# RDTO: -0.18449082493554392
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 352892.56198347104
# Dinero Final Débil: $ 491301.4316495609
# Dinero Total Final: $ 844193.993633032
# Diferencia con el Capital Inicial: $ -155806.00636696804
# RDTO: -0.15580600636696806
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 362924.8286654795
# Dinero Final Débil: $ 621169.0405809954
# Dinero Total Final: $ 984093.8692464749
# Diferencia con el Capital Inicial: $ -15906.130753525067
# RDTO: -0.015906130753525094
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 378490.26897303364
# Dinero Final Débil: $ 708058.068220964
# Dinero Total Final: $ 1086548.3371939976
# Diferencia con el Capital Inicial: $ 86548.33719399758
# RDTO: 0.08654833719399768
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 340236.1795704408
# Dinero Final Débil: $ 1069947.2178776274
# Dinero Total Final: $ 1410183.397448068
# Diferencia con el Capital Inicial: $ 410183.397448068
# RDTO: 0.410183397448068
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 380902.9203823637
# Dinero Final Débil: $ 950898.6344863195
# Dinero Total Final: $ 1331801.5548686832
# Diferencia con el Capital Inicial: $ 331801.5548686832
# RDTO: 0.33180155486868324
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 364861.7526704109
# Dinero Final Débil: $ 620525.4162099513
# Dinero Total Final: $ 985387.1688803622
# Diferencia con el Capital Inicial: $ -14612.83111963782
# RDTO: -0.014612831119637848
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 353619.19173727627
# Dinero Final Débil: $ 936053.7861423834
# Dinero Total Final: $ 1289672.9778796597
# Diferencia con el Capital Inicial: $ 289672.97787965974
# RDTO: 0.28967297787965984
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 345301.8979813942
# Dinero Final Débil: $ 312043.4745091207
# Dinero Total Final: $ 657345.3724905149
# Diferencia con el Capital Inicial: $ -342654.6275094851
# RDTO: -0.34265462750948517
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 307342.37666043115
# Dinero Final Débil: $ 501662.35747045156
# Dinero Total Final: $ 809004.7341308827
# Diferencia con el Capital Inicial: $ -190995.26586911734
# RDTO: -0.1909952658691173
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 360477.8620036179
# Dinero Final Débil: $ 602524.7438459148
# Dinero Total Final: $ 963002.6058495328
# Diferencia con el Capital Inicial: $ -36997.39415046724
# RDTO: -0.03699739415046721
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 811886.2777511316
# Dinero Total Final: $ 1161886.2777511314
# Diferencia con el Capital Inicial: $ 161886.27775113145
# RDTO: 0.1618862777511314
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1077666.25558638
# Dinero Total Final: $ 1427666.25558638
# Diferencia con el Capital Inicial: $ 427666.2555863799
# RDTO: 0.42766625558637994
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 649364.8296867908
# Dinero Total Final: $ 999364.8296867908
# Diferencia con el Capital Inicial: $ -635.1703132091789
# RDTO: -0.0006351703132091435
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 331382.97872340423
# Dinero Final Débil: $ 348141.3041201668
# Dinero Total Final: $ 679524.282843571
# Diferencia con el Capital Inicial: $ -320475.71715642896
# RDTO: -0.320475717156429
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 589934.5873253411
# Dinero Total Final: $ 939934.5873253411
# Diferencia con el Capital Inicial: $ -60065.41267465893
# RDTO: -0.060065412674658925
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1131093.1529590008
# Dinero Total Final: $ 1481093.1529590008
# Diferencia con el Capital Inicial: $ 481093.1529590008
# RDTO: 0.4810931529590008
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1057378.2271315502
# Dinero Total Final: $ 1407378.2271315502
# Diferencia con el Capital Inicial: $ 407378.2271315502
# RDTO: 0.40737822713155025
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 723543.0847090983
# Dinero Total Final: $ 1073543.0847090983
# Diferencia con el Capital Inicial: $ 73543.08470909833
# RDTO: 0.07354308470909832
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 644824.1782764078
# Dinero Total Final: $ 994824.1782764078
# Diferencia con el Capital Inicial: $ -5175.821723592235
# RDTO: -0.005175821723592211
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 703929.6180667396
# Dinero Total Final: $ 1053929.6180667398
# Diferencia con el Capital Inicial: $ 53929.61806673976
# RDTO: 0.05392961806673968
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 340890.4109589041
# Dinero Final Débil: $ 433889.6697638009
# Dinero Total Final: $ 774780.080722705
# Diferencia con el Capital Inicial: $ -225219.919277295
# RDTO: -0.225219919277295
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 355907.1729957806
# Dinero Final Débil: $ 573558.6649019506
# Dinero Total Final: $ 929465.8378977312
# Diferencia con el Capital Inicial: $ -70534.16210226878
# RDTO: -0.07053416210226882
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 714033.026068371
# Dinero Total Final: $ 1064033.026068371
# Diferencia con el Capital Inicial: $ 64033.02606837102
# RDTO: 0.06403302606837102
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 572220.8589431564
# Dinero Total Final: $ 922220.8589431564
# Diferencia con el Capital Inicial: $ -77779.14105684357
# RDTO: -0.07777914105684358
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 327409.0565947887
# Dinero Final Débil: $ 313527.13702261576
# Dinero Total Final: $ 640936.1936174044
# Diferencia con el Capital Inicial: $ -359063.80638259556
# RDTO: -0.3590638063825956
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 340147.7146042363
# Dinero Final Débil: $ 446812.41758006444
# Dinero Total Final: $ 786960.1321843008
# Diferencia con el Capital Inicial: $ -213039.8678156992
# RDTO: -0.21303986781569917
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 314854.0948277475
# Dinero Total Final: $ 664854.0948277474
# Diferencia con el Capital Inicial: $ -335145.90517225256
# RDTO: -0.3351459051722525
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 669619.4694529452
# Dinero Total Final: $ 1019619.4694529452
# Diferencia con el Capital Inicial: $ 19619.469452945166
# RDTO: 0.019619469452945237
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 344760.4790419162
# Dinero Final Débil: $ 294110.70066377096
# Dinero Total Final: $ 638871.1797056871
# Diferencia con el Capital Inicial: $ -361128.8202943129
# RDTO: -0.3611288202943129
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 321066.7226863182
# Dinero Final Débil: $ 226520.90353868937
# Dinero Total Final: $ 547587.6262250076
# Diferencia con el Capital Inicial: $ -452412.3737749924
# RDTO: -0.45241237377499244
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 285835.44498673524
# Dinero Final Débil: $ 418123.0043795699
# Dinero Total Final: $ 703958.4493663051
# Diferencia con el Capital Inicial: $ -296041.55063369486
# RDTO: -0.29604155063369486
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 323000.55021394783
# Dinero Final Débil: $ 748154.4541060615
# Dinero Total Final: $ 1071155.0043200094
# Diferencia con el Capital Inicial: $ 71155.00432000938
# RDTO: 0.07115500432000932
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 316586.0311312482
# Dinero Final Débil: $ 726049.3557022025
# Dinero Total Final: $ 1042635.3868334508
# Diferencia con el Capital Inicial: $ 42635.38683345076
# RDTO: 0.042635386833450806
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 222638.46042655097
# Dinero Final Débil: $ 448946.465869487
# Dinero Total Final: $ 671584.926296038
# Diferencia con el Capital Inicial: $ -328415.073703962
# RDTO: -0.32841507370396206
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 295648.552583586
# Dinero Final Débil: $ 506105.32112196693
# Dinero Total Final: $ 801753.8737055529
# Diferencia con el Capital Inicial: $ -198246.1262944471
# RDTO: -0.19824612629444716
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 241679.88560710388
# Dinero Final Débil: $ 604917.4745841547
# Dinero Total Final: $ 846597.3601912586
# Diferencia con el Capital Inicial: $ -153402.6398087414
# RDTO: -0.15340263980874136
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 380309.4700491433
# Dinero Final Débil: $ 975393.5794826683
# Dinero Total Final: $ 1355703.0495318116
# Diferencia con el Capital Inicial: $ 355703.0495318116
# RDTO: 0.35570304953181164

# %% [markdown]
# Para el 2019

# %%
for i in range(60, 260, 5):
    Backtesting(1000000, i , df_2019)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 650000.0
# Dinero Total Final: $ 1000000.0
# Diferencia con el Capital Inicial: $ 0.0
# RDTO: 0.0

# %% [markdown]
# Para el 2020

# %%
for i in range(60, 260, 5):
    Backtesting(1000000, i , df_2020)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 949876.0303154463
# Dinero Total Final: $ 1299876.0303154462
# Diferencia con el Capital Inicial: $ 299876.0303154462
# RDTO: 0.2998760303154462
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 430163.43499747897
# Dinero Final Débil: $ 715220.7655808649
# Dinero Total Final: $ 1145384.2005783438
# Diferencia con el Capital Inicial: $ 145384.20057834382
# RDTO: 0.1453842005783439
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 371067.6686134645
# Dinero Final Débil: $ 938372.8960005523
# Dinero Total Final: $ 1309440.5646140168
# Diferencia con el Capital Inicial: $ 309440.5646140168
# RDTO: 0.3094405646140168
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 442001.3209887943
# Dinero Final Débil: $ 291933.4327198124
# Dinero Total Final: $ 733934.7537086067
# Diferencia con el Capital Inicial: $ -266065.2462913933
# RDTO: -0.2660652462913933
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 376196.6241146825
# Dinero Final Débil: $ 471444.3619568709
# Dinero Total Final: $ 847640.9860715533
# Diferencia con el Capital Inicial: $ -152359.0139284467
# RDTO: -0.15235901392844664
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 390079.8149871676
# Dinero Final Débil: $ 1381164.7858640691
# Dinero Total Final: $ 1771244.6008512368
# Diferencia con el Capital Inicial: $ 771244.6008512368
# RDTO: 0.7712446008512368
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 597054.1868632792
# Dinero Final Débil: $ 1295589.3073778965
# Dinero Total Final: $ 1892643.4942411757
# Diferencia con el Capital Inicial: $ 892643.4942411757
# RDTO: 0.8926434942411756
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 431983.00143228786
# Dinero Final Débil: $ 800804.7927639694
# Dinero Total Final: $ 1232787.7941962574
# Diferencia con el Capital Inicial: $ 232787.79419625737
# RDTO: 0.23278779419625728
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 405474.80073972646
# Dinero Final Débil: $ 1440440.4443986134
# Dinero Total Final: $ 1845915.24513834
# Diferencia con el Capital Inicial: $ 845915.2451383399
# RDTO: 0.8459152451383398
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 372597.92338302336
# Dinero Final Débil: $ 500932.6003199394
# Dinero Total Final: $ 873530.5237029628
# Diferencia con el Capital Inicial: $ -126469.47629703721
# RDTO: -0.1264694762970372
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 311948.43769081804
# Dinero Final Débil: $ 317872.49155836727
# Dinero Total Final: $ 629820.9292491854
# Diferencia con el Capital Inicial: $ -370179.07075081463
# RDTO: -0.3701790707508146
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 570236.8198411792
# Dinero Final Débil: $ 1545847.1362810188
# Dinero Total Final: $ 2116083.956122198
# Diferencia con el Capital Inicial: $ 1116083.9561221981
# RDTO: 1.116083956122198
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 264235.5883225808
# Dinero Final Débil: $ 105048.32506109013
# Dinero Total Final: $ 369283.9133836709
# Diferencia con el Capital Inicial: $ -630716.0866163292
# RDTO: -0.630716086616329
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 962232.2605121711
# Dinero Total Final: $ 1312232.260512171
# Diferencia con el Capital Inicial: $ 312232.2605121711
# RDTO: 0.312232260512171
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 352830.6593706313
# Dinero Final Débil: $ 357102.1497518094
# Dinero Total Final: $ 709932.8091224408
# Diferencia con el Capital Inicial: $ -290067.19087755925
# RDTO: -0.2900671908775593
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 419811.4729760622
# Dinero Final Débil: $ 1219810.881146148
# Dinero Total Final: $ 1639622.3541222103
# Diferencia con el Capital Inicial: $ 639622.3541222103
# RDTO: 0.6396223541222104
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 370335.03333142324
# Dinero Final Débil: $ 1071376.1342957288
# Dinero Total Final: $ 1441711.167627152
# Diferencia con el Capital Inicial: $ 441711.16762715206
# RDTO: 0.4417111676271521
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 337566.4618645638
# Dinero Final Débil: $ 1055437.337745618
# Dinero Total Final: $ 1393003.799610182
# Diferencia con el Capital Inicial: $ 393003.79961018194
# RDTO: 0.39300379961018184
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 539644.5377169774
# Dinero Final Débil: $ 1472566.008775895
# Dinero Total Final: $ 2012210.5464928723
# Diferencia con el Capital Inicial: $ 1012210.5464928723
# RDTO: 1.0122105464928723
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 398856.8800512162
# Dinero Final Débil: $ 768180.5424649643
# Dinero Total Final: $ 1167037.4225161807
# Diferencia con el Capital Inicial: $ 167037.42251618067
# RDTO: 0.1670374225161806
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 358970.05605657224
# Dinero Final Débil: $ 912247.1163767186
# Dinero Total Final: $ 1271217.1724332909
# Diferencia con el Capital Inicial: $ 271217.17243329086
# RDTO: 0.2712171724332908
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 309805.1575768139
# Dinero Final Débil: $ 746985.9098280007
# Dinero Total Final: $ 1056791.0674048145
# Diferencia con el Capital Inicial: $ 56791.06740481453
# RDTO: 0.05679106740481443
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 316579.3643347824
# Dinero Final Débil: $ 491733.65343994455
# Dinero Total Final: $ 808313.017774727
# Diferencia con el Capital Inicial: $ -191686.98222527304
# RDTO: -0.19168698222527303
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 402805.9980819453
# Dinero Final Débil: $ 1118900.2582673065
# Dinero Total Final: $ 1521706.2563492518
# Diferencia con el Capital Inicial: $ 521706.25634925184
# RDTO: 0.5217062563492518
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 405843.13503427233
# Dinero Final Débil: $ 809891.2359905102
# Dinero Total Final: $ 1215734.3710247825
# Diferencia con el Capital Inicial: $ 215734.37102478254
# RDTO: 0.21573437102478255
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 278607.7946357116
# Dinero Final Débil: $ 432966.5504740119
# Dinero Total Final: $ 711574.3451097235
# Diferencia con el Capital Inicial: $ -288425.6548902765
# RDTO: -0.2884256548902765
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 306911.9669876204
# Dinero Final Débil: $ 1337912.6893707663
# Dinero Total Final: $ 1644824.6563583866
# Diferencia con el Capital Inicial: $ 644824.6563583866
# RDTO: 0.6448246563583866
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 449431.7570165321
# Dinero Final Débil: $ 1222711.4951166366
# Dinero Total Final: $ 1672143.2521331687
# Diferencia con el Capital Inicial: $ 672143.2521331687
# RDTO: 0.6721432521331687
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 368468.76011654263
# Dinero Final Débil: $ 1124969.9451246199
# Dinero Total Final: $ 1493438.7052411626
# Diferencia con el Capital Inicial: $ 493438.70524116256
# RDTO: 0.4934387052411626
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 354412.66912669124
# Dinero Final Débil: $ 509051.603981379
# Dinero Total Final: $ 863464.2731080703
# Diferencia con el Capital Inicial: $ -136535.72689192975
# RDTO: -0.13653572689192972
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 434777.34701848135
# Dinero Final Débil: $ 628579.3951317016
# Dinero Total Final: $ 1063356.7421501828
# Diferencia con el Capital Inicial: $ 63356.742150182836
# RDTO: 0.06335674215018283
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 387462.6460201032
# Dinero Final Débil: $ 1256876.1915657392
# Dinero Total Final: $ 1644338.8375858425
# Diferencia con el Capital Inicial: $ 644338.8375858425
# RDTO: 0.6443388375858425
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 367424.57133868174
# Dinero Final Débil: $ 1051545.5252075733
# Dinero Total Final: $ 1418970.096546255
# Diferencia con el Capital Inicial: $ 418970.09654625505
# RDTO: 0.41897009654625506
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 462583.60950425046
# Dinero Final Débil: $ 954179.7972166986
# Dinero Total Final: $ 1416763.406720949
# Diferencia con el Capital Inicial: $ 416763.4067209491
# RDTO: 0.41676340672094914
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 356543.15924103186
# Dinero Final Débil: $ 691503.6085760047
# Dinero Total Final: $ 1048046.7678170366
# Diferencia con el Capital Inicial: $ 48046.7678170366
# RDTO: 0.04804676781703665
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 437102.7490039115
# Dinero Final Débil: $ 1052259.8695044932
# Dinero Total Final: $ 1489362.6185084046
# Diferencia con el Capital Inicial: $ 489362.6185084046
# RDTO: 0.48936261850840457
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 418396.02428047784
# Dinero Final Débil: $ 952302.8619369052
# Dinero Total Final: $ 1370698.886217383
# Diferencia con el Capital Inicial: $ 370698.88621738297
# RDTO: 0.370698886217383
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 401173.7752335985
# Dinero Final Débil: $ 850046.1847601214
# Dinero Total Final: $ 1251219.9599937198
# Diferencia con el Capital Inicial: $ 251219.95999371982
# RDTO: 0.25121995999371993
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 361631.94348258025
# Dinero Final Débil: $ 896203.06435928
# Dinero Total Final: $ 1257835.0078418604
# Diferencia con el Capital Inicial: $ 257835.0078418604
# RDTO: 0.2578350078418603
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 832362.166783389
# Dinero Total Final: $ 1182362.1667833892
# Diferencia con el Capital Inicial: $ 182362.16678338917
# RDTO: 0.18236216678338923

# %% [markdown]
# Para 2021

# %%
for i in range(60, 255, 5):
    Backtesting(1000000, i , df_2021)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 384217.7550255962
# Dinero Final Débil: $ 1052927.3156162144
# Dinero Total Final: $ 1437145.0706418105
# Diferencia con el Capital Inicial: $ 437145.07064181054
# RDTO: 0.4371450706418105
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 260914.87547744915
# Dinero Final Débil: $ 657077.0098934635
# Dinero Total Final: $ 917991.8853709126
# Diferencia con el Capital Inicial: $ -82008.11462908739
# RDTO: -0.08200811462908741
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 359894.4369908872
# Dinero Final Débil: $ 547083.8657310506
# Dinero Total Final: $ 906978.3027219379
# Diferencia con el Capital Inicial: $ -93021.69727806211
# RDTO: -0.09302169727806209
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 340490.10824806924
# Dinero Final Débil: $ 277766.57479734067
# Dinero Total Final: $ 618256.6830454099
# Diferencia con el Capital Inicial: $ -381743.31695459015
# RDTO: -0.3817433169545902
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 340006.8414451409
# Dinero Final Débil: $ 879291.1422920512
# Dinero Total Final: $ 1219297.9837371921
# Diferencia con el Capital Inicial: $ 219297.98373719212
# RDTO: 0.21929798373719223
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 468086.8650024175
# Dinero Final Débil: $ 1073225.5977655146
# Dinero Total Final: $ 1541312.462767932
# Diferencia con el Capital Inicial: $ 541312.4627679321
# RDTO: 0.541312462767932
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 399304.6032735169
# Dinero Final Débil: $ 876981.4173948225
# Dinero Total Final: $ 1276286.0206683394
# Diferencia con el Capital Inicial: $ 276286.02066833945
# RDTO: 0.2762860206683395
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 267000.7768958877
# Dinero Final Débil: $ 449985.37761477736
# Dinero Total Final: $ 716986.154510665
# Diferencia con el Capital Inicial: $ -283013.845489335
# RDTO: -0.28301384548933506
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 436155.99547586264
# Dinero Final Débil: $ 726150.883695155
# Dinero Total Final: $ 1162306.8791710176
# Diferencia con el Capital Inicial: $ 162306.87917101756
# RDTO: 0.1623068791710176
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 344800.99111058505
# Dinero Final Débil: $ 818468.5204723399
# Dinero Total Final: $ 1163269.511582925
# Diferencia con el Capital Inicial: $ 163269.51158292498
# RDTO: 0.16326951158292502
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 285503.1524688926
# Dinero Final Débil: $ 305510.464534816
# Dinero Total Final: $ 591013.6170037086
# Diferencia con el Capital Inicial: $ -408986.3829962914
# RDTO: -0.4089863829962914
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 416864.6070348476
# Dinero Final Débil: $ 843191.8028201592
# Dinero Total Final: $ 1260056.4098550067
# Diferencia con el Capital Inicial: $ 260056.40985500673
# RDTO: 0.26005640985500666
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 315104.2428608101
# Dinero Final Débil: $ 556793.6995128869
# Dinero Total Final: $ 871897.942373697
# Diferencia con el Capital Inicial: $ -128102.05762630305
# RDTO: -0.128102057626303
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 430021.36752136756
# Dinero Final Débil: $ 861621.1468955633
# Dinero Total Final: $ 1291642.514416931
# Diferencia con el Capital Inicial: $ 291642.51441693096
# RDTO: 0.291642514416931
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 338713.30845617456
# Dinero Final Débil: $ 574148.1721909851
# Dinero Total Final: $ 912861.4806471596
# Diferencia con el Capital Inicial: $ -87138.51935284038
# RDTO: -0.08713851935284034
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 285107.0299424458
# Dinero Final Débil: $ -180615.791163351
# Dinero Total Final: $ 104491.2387790948
# Diferencia con el Capital Inicial: $ -895508.7612209052
# RDTO: -0.8955087612209052
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 405208.03010134347
# Dinero Final Débil: $ 1224479.894462808
# Dinero Total Final: $ 1629687.9245641516
# Diferencia con el Capital Inicial: $ 629687.9245641516
# RDTO: 0.6296879245641516
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350100.57471264375
# Dinero Final Débil: $ 589070.1776595855
# Dinero Total Final: $ 939170.7523722292
# Diferencia con el Capital Inicial: $ -60829.24762777076
# RDTO: -0.060829247627770755
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 374971.3224357471
# Dinero Final Débil: $ 847725.1694521914
# Dinero Total Final: $ 1222696.4918879385
# Diferencia con el Capital Inicial: $ 222696.49188793846
# RDTO: 0.22269649188793839
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 321342.5785574196
# Dinero Final Débil: $ 725706.9559932179
# Dinero Total Final: $ 1047049.5345506375
# Diferencia con el Capital Inicial: $ 47049.53455063747
# RDTO: 0.04704953455063743
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 372621.0908864404
# Dinero Final Débil: $ 479601.12782562006
# Dinero Total Final: $ 852222.2187120605
# Diferencia con el Capital Inicial: $ -147777.78128793952
# RDTO: -0.1477777812879395
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 366440.11729055544
# Dinero Final Débil: $ 798135.1367471428
# Dinero Total Final: $ 1164575.2540376983
# Diferencia con el Capital Inicial: $ 164575.25403769827
# RDTO: 0.16457525403769835
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 358546.0374336509
# Dinero Final Débil: $ 719693.2061161912
# Dinero Total Final: $ 1078239.2435498422
# Diferencia con el Capital Inicial: $ 78239.24354984215
# RDTO: 0.07823924354984224
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 280328.97700035694
# Dinero Final Débil: $ 504463.0079612703
# Dinero Total Final: $ 784791.9849616273
# Diferencia con el Capital Inicial: $ -215208.01503837272
# RDTO: -0.21520801503837272
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 286722.47927155375
# Dinero Final Débil: $ 600287.8917687623
# Dinero Total Final: $ 887010.3710403161
# Diferencia con el Capital Inicial: $ -112989.62895968393
# RDTO: -0.1129896289596839
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 413131.1795335011
# Dinero Final Débil: $ 836479.1234886765
# Dinero Total Final: $ 1249610.3030221777
# Diferencia con el Capital Inicial: $ 249610.30302217766
# RDTO: 0.24961030302217768
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 506416.8324674369
# Dinero Total Final: $ 856416.8324674369
# Diferencia con el Capital Inicial: $ -143583.1675325631
# RDTO: -0.14358316753256306
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 891291.624207889
# Dinero Total Final: $ 1241291.624207889
# Diferencia con el Capital Inicial: $ 241291.62420788896
# RDTO: 0.24129162420788886
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 743200.2766853431
# Dinero Total Final: $ 1093200.2766853431
# Diferencia con el Capital Inicial: $ 93200.27668534312
# RDTO: 0.09320027668534303
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 627594.6779377743
# Dinero Total Final: $ 977594.6779377743
# Diferencia con el Capital Inicial: $ -22405.322062225663
# RDTO: -0.022405322062225674
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 335435.3393085788
# Dinero Final Débil: $ 592308.5835747606
# Dinero Total Final: $ 927743.9228833395
# Diferencia con el Capital Inicial: $ -72256.07711666054
# RDTO: -0.07225607711666049
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 339245.1569806279
# Dinero Final Débil: $ 887195.7175820328
# Dinero Total Final: $ 1226440.8745626607
# Diferencia con el Capital Inicial: $ 226440.8745626607
# RDTO: 0.2264408745626607
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 349900.42888998904
# Dinero Final Débil: $ 891509.853333907
# Dinero Total Final: $ 1241410.2822238961
# Diferencia con el Capital Inicial: $ 241410.28222389612
# RDTO: 0.24141028222389616
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 336137.62108940765
# Dinero Final Débil: $ 519285.22059499513
# Dinero Total Final: $ 855422.8416844028
# Diferencia con el Capital Inicial: $ -144577.15831559722
# RDTO: -0.14457715831559725
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 326282.952559975
# Dinero Final Débil: $ 425792.4821499052
# Dinero Total Final: $ 752075.4347098802
# Diferencia con el Capital Inicial: $ -247924.56529011985
# RDTO: -0.24792456529011986
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 351022.2421927657
# Dinero Final Débil: $ 407639.91263767116
# Dinero Total Final: $ 758662.1548304369
# Diferencia con el Capital Inicial: $ -241337.84516956308
# RDTO: -0.24133784516956303
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 348275.0896057348
# Dinero Final Débil: $ 594648.876514556
# Dinero Total Final: $ 942923.9661202908
# Diferencia con el Capital Inicial: $ -57076.0338797092
# RDTO: -0.057076033879709165
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 319252.95793970313
# Dinero Final Débil: $ 596640.4237047106
# Dinero Total Final: $ 915893.3816444137
# Diferencia con el Capital Inicial: $ -84106.61835558631
# RDTO: -0.0841066183555863
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1100066.8934976368
# Dinero Total Final: $ 1450066.8934976368
# Diferencia con el Capital Inicial: $ 450066.8934976368
# RDTO: 0.45006689349763684

# %% [markdown]
# Para el 2022

# %%
for i in range(60, 260, 5):
    Backtesting(1000000, i , df_2022)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 910244.0249458773
# Dinero Total Final: $ 1260244.0249458773
# Diferencia con el Capital Inicial: $ 260244.02494587726
# RDTO: 0.2602440249458773
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 347971.67819675856
# Dinero Final Débil: $ 929933.3750694722
# Dinero Total Final: $ 1277905.0532662307
# Diferencia con el Capital Inicial: $ 277905.05326623074
# RDTO: 0.27790505326623083
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 395485.5973803868
# Dinero Final Débil: $ 1041099.940941532
# Dinero Total Final: $ 1436585.5383219188
# Diferencia con el Capital Inicial: $ 436585.5383219188
# RDTO: 0.4365855383219188
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 283484.04636829504
# Dinero Final Débil: $ -284254.8432205077
# Dinero Total Final: $ -770.7968522126903
# Diferencia con el Capital Inicial: $ -1000770.7968522126
# RDTO: -1.0007707968522126
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 417610.32019228785
# Dinero Final Débil: $ 554568.0903084258
# Dinero Total Final: $ 972178.4105007136
# Diferencia con el Capital Inicial: $ -27821.589499286376
# RDTO: -0.02782158949928637
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 319296.4967245799
# Dinero Final Débil: $ -167932.64690200976
# Dinero Total Final: $ 151363.84982257013
# Diferencia con el Capital Inicial: $ -848636.1501774299
# RDTO: -0.8486361501774299
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 401760.08225983795
# Dinero Final Débil: $ 749915.0592686386
# Dinero Total Final: $ 1151675.1415284765
# Diferencia con el Capital Inicial: $ 151675.1415284765
# RDTO: 0.1516751415284765
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 362795.23954836745
# Dinero Final Débil: $ 1196733.012745703
# Dinero Total Final: $ 1559528.2522940706
# Diferencia con el Capital Inicial: $ 559528.2522940706
# RDTO: 0.5595282522940705
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 374348.2583849781
# Dinero Final Débil: $ 874854.786841323
# Dinero Total Final: $ 1249203.045226301
# Diferencia con el Capital Inicial: $ 249203.04522630107
# RDTO: 0.249203045226301
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 430388.12774697825
# Dinero Final Débil: $ 1105197.7834799362
# Dinero Total Final: $ 1535585.9112269145
# Diferencia con el Capital Inicial: $ 535585.9112269145
# RDTO: 0.5355859112269146
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 117699.7346229453
# Dinero Final Débil: $ 71772.05192503537
# Dinero Total Final: $ 189471.78654798068
# Diferencia con el Capital Inicial: $ -810528.2134520193
# RDTO: -0.8105282134520193
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 291334.80574129324
# Dinero Final Débil: $ 544382.2490593974
# Dinero Total Final: $ 835717.0548006906
# Diferencia con el Capital Inicial: $ -164282.94519930938
# RDTO: -0.16428294519930942
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 434433.70842142653
# Dinero Final Débil: $ 762823.3398883416
# Dinero Total Final: $ 1197257.048309768
# Diferencia con el Capital Inicial: $ 197257.04830976808
# RDTO: 0.19725704830976798
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 483172.45842793374
# Dinero Total Final: $ 833172.4584279337
# Diferencia con el Capital Inicial: $ -166827.54157206626
# RDTO: -0.16682754157206625
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 333154.46715023014
# Dinero Final Débil: $ 370797.32820315653
# Dinero Total Final: $ 703951.7953533867
# Diferencia con el Capital Inicial: $ -296048.20464661333
# RDTO: -0.2960482046466133
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 403664.05472986965
# Dinero Final Débil: $ 690354.4947122618
# Dinero Total Final: $ 1094018.5494421315
# Diferencia con el Capital Inicial: $ 94018.54944213154
# RDTO: 0.0940185494421315
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 358788.5886207134
# Dinero Final Débil: $ 1000402.6704430103
# Dinero Total Final: $ 1359191.2590637237
# Diferencia con el Capital Inicial: $ 359191.25906372373
# RDTO: 0.3591912590637236
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 442831.84760043956
# Dinero Final Débil: $ 1114883.3903920262
# Dinero Total Final: $ 1557715.2379924657
# Diferencia con el Capital Inicial: $ 557715.2379924657
# RDTO: 0.5577152379924657
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 397580.6451612903
# Dinero Final Débil: $ 544713.6219948344
# Dinero Total Final: $ 942294.2671561247
# Diferencia con el Capital Inicial: $ -57705.7328438753
# RDTO: -0.05770573284387526
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 390635.85854131763
# Dinero Final Débil: $ 808645.8771083129
# Dinero Total Final: $ 1199281.7356496304
# Diferencia con el Capital Inicial: $ 199281.73564963043
# RDTO: 0.19928173564963036
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 379640.9759641582
# Dinero Final Débil: $ 596049.1995086768
# Dinero Total Final: $ 975690.175472835
# Diferencia con el Capital Inicial: $ -24309.824527165038
# RDTO: -0.024309824527165014
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 317073.48884896655
# Dinero Final Débil: $ 513408.0886795708
# Dinero Total Final: $ 830481.5775285374
# Diferencia con el Capital Inicial: $ -169518.42247146263
# RDTO: -0.16951842247146265
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 311974.4847396275
# Dinero Final Débil: $ 346460.5823795475
# Dinero Total Final: $ 658435.067119175
# Diferencia con el Capital Inicial: $ -341564.932880825
# RDTO: -0.341564932880825
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 921334.8928486529
# Dinero Total Final: $ 1271334.8928486528
# Diferencia con el Capital Inicial: $ 271334.8928486528
# RDTO: 0.27133489284865275
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 344405.2044609666
# Dinero Final Débil: $ 227439.80925705653
# Dinero Total Final: $ 571845.0137180231
# Diferencia con el Capital Inicial: $ -428154.9862819769
# RDTO: -0.4281549862819769
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 324744.99433320743
# Dinero Final Débil: $ 406418.079256567
# Dinero Total Final: $ 731163.0735897744
# Diferencia con el Capital Inicial: $ -268836.92641022557
# RDTO: -0.2688369264102256
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 936733.1119812471
# Dinero Total Final: $ 1286733.111981247
# Diferencia con el Capital Inicial: $ 286733.1119812471
# RDTO: 0.28673311198124707
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 363732.63547624525
# Dinero Total Final: $ 713732.6354762453
# Diferencia con el Capital Inicial: $ -286267.3645237547
# RDTO: -0.2862673645237547
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 355555.6699670847
# Dinero Final Débil: $ 575799.568478714
# Dinero Total Final: $ 931355.2384457986
# Diferencia con el Capital Inicial: $ -68644.76155420137
# RDTO: -0.0686447615542014
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 395359.6610937307
# Dinero Final Débil: $ 880813.3131202069
# Dinero Total Final: $ 1276172.9742139378
# Diferencia con el Capital Inicial: $ 276172.97421393776
# RDTO: 0.2761729742139378
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 413976.7279595352
# Dinero Final Débil: $ 804062.1008305934
# Dinero Total Final: $ 1218038.8287901287
# Diferencia con el Capital Inicial: $ 218038.8287901287
# RDTO: 0.2180388287901287
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 420130.6974089147
# Dinero Final Débil: $ 1391440.8770314688
# Dinero Total Final: $ 1811571.5744403834
# Diferencia con el Capital Inicial: $ 811571.5744403834
# RDTO: 0.8115715744403833
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 371803.6844166913
# Dinero Final Débil: $ 304641.46812845534
# Dinero Total Final: $ 676445.1525451466
# Diferencia con el Capital Inicial: $ -323554.84745485336
# RDTO: -0.3235548474548533
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 341873.9587494743
# Dinero Final Débil: $ 710088.8502456406
# Dinero Total Final: $ 1051962.8089951149
# Diferencia con el Capital Inicial: $ 51962.80899511487
# RDTO: 0.05196280899511496
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 343151.25235589687
# Dinero Final Débil: $ 501933.7749901485
# Dinero Total Final: $ 845085.0273460454
# Diferencia con el Capital Inicial: $ -154914.97265395464
# RDTO: -0.1549149726539546
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350238.09523809527
# Dinero Final Débil: $ 509807.62388653867
# Dinero Total Final: $ 860045.7191246339
# Diferencia con el Capital Inicial: $ -139954.28087536606
# RDTO: -0.1399542808753661
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 352855.20054384775
# Dinero Final Débil: $ 638889.7919636078
# Dinero Total Final: $ 991744.9925074555
# Diferencia con el Capital Inicial: $ -8255.007492544479
# RDTO: -0.008255007492544486
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 611550.5342993808
# Dinero Total Final: $ 961550.5342993808
# Diferencia con el Capital Inicial: $ -38449.465700619156
# RDTO: -0.038449465700619134
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 398267.97385620914
# Dinero Final Débil: $ 725041.3107343136
# Dinero Total Final: $ 1123309.2845905228
# Diferencia con el Capital Inicial: $ 123309.28459052276
# RDTO: 0.12330928459052282
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 586084.2358700228
# Dinero Total Final: $ 936084.2358700228
# Diferencia con el Capital Inicial: $ -63915.76412997721
# RDTO: -0.06391576412997724

# %% [markdown]
# Para el 2023

# %%
for i in range(60, 260, 5):
    Backtesting(1000000, i , df_2023)
# Out:
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 741939.9776548421
# Dinero Total Final: $ 1091939.9776548422
# Diferencia con el Capital Inicial: $ 91939.9776548422
# RDTO: 0.09193997765484219
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 361058.39779926726
# Dinero Final Débil: $ 687376.2399563454
# Dinero Total Final: $ 1048434.6377556126
# Diferencia con el Capital Inicial: $ 48434.63775561261
# RDTO: 0.04843463775561263
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 372899.065219182
# Dinero Final Débil: $ 976287.3214276835
# Dinero Total Final: $ 1349186.3866468654
# Diferencia con el Capital Inicial: $ 349186.3866468654
# RDTO: 0.3491863866468654
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 307522.55377455434
# Dinero Final Débil: $ 910810.0740109651
# Dinero Total Final: $ 1218332.6277855195
# Diferencia con el Capital Inicial: $ 218332.62778551946
# RDTO: 0.21833262778551954
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 306766.31861755694
# Dinero Final Débil: $ 1002557.8341688893
# Dinero Total Final: $ 1309324.1527864463
# Diferencia con el Capital Inicial: $ 309324.15278644627
# RDTO: 0.3093241527864463
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 437302.5617066498
# Dinero Final Débil: $ 873307.0126181929
# Dinero Total Final: $ 1310609.5743248428
# Diferencia con el Capital Inicial: $ 310609.5743248428
# RDTO: 0.3106095743248427
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 268475.03590716945
# Dinero Final Débil: $ 843858.0524730661
# Dinero Total Final: $ 1112333.0883802357
# Diferencia con el Capital Inicial: $ 112333.08838023571
# RDTO: 0.11233308838023581
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 353815.74240592384
# Dinero Final Débil: $ 600613.5843875334
# Dinero Total Final: $ 954429.3267934571
# Diferencia con el Capital Inicial: $ -45570.67320654285
# RDTO: -0.045570673206542844
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 355044.61221688404
# Dinero Final Débil: $ 811328.144547768
# Dinero Total Final: $ 1166372.7567646522
# Diferencia con el Capital Inicial: $ 166372.7567646522
# RDTO: 0.16637275676465224
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 353403.5656401945
# Dinero Final Débil: $ 746456.3431343399
# Dinero Total Final: $ 1099859.9087745345
# Diferencia con el Capital Inicial: $ 99859.90877453447
# RDTO: 0.09985990877453443
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 863002.388112143
# Dinero Total Final: $ 1213002.3881121431
# Diferencia con el Capital Inicial: $ 213002.38811214315
# RDTO: 0.21300238811214323
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 326505.5999372126
# Dinero Final Débil: $ 610322.1557020812
# Dinero Total Final: $ 936827.7556392937
# Diferencia con el Capital Inicial: $ -63172.2443607063
# RDTO: -0.06317224436070634
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 375259.5083239045
# Dinero Final Débil: $ 594080.6034778433
# Dinero Total Final: $ 969340.1118017478
# Diferencia con el Capital Inicial: $ -30659.888198252185
# RDTO: -0.03065988819825216
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 348318.65492393915
# Dinero Final Débil: $ 894995.0407344752
# Dinero Total Final: $ 1243313.6956584144
# Diferencia con el Capital Inicial: $ 243313.6956584144
# RDTO: 0.24331369565841432
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 570526.9198493283
# Dinero Total Final: $ 920526.9198493283
# Diferencia con el Capital Inicial: $ -79473.08015067165
# RDTO: -0.07947308015067167
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 363296.08938547486
# Dinero Final Débil: $ 911091.4959023776
# Dinero Total Final: $ 1274387.5852878524
# Diferencia con el Capital Inicial: $ 274387.58528785245
# RDTO: 0.27438758528785234
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 352213.73039926204
# Dinero Final Débil: $ 431410.8485193863
# Dinero Total Final: $ 783624.5789186484
# Diferencia con el Capital Inicial: $ -216375.42108135158
# RDTO: -0.21637542108135155
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 1214672.968873997
# Dinero Total Final: $ 1564672.968873997
# Diferencia con el Capital Inicial: $ 564672.968873997
# RDTO: 0.5646729688739971
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 349832.21755522734
# Dinero Final Débil: $ 930075.3739514173
# Dinero Total Final: $ 1279907.5915066446
# Diferencia con el Capital Inicial: $ 279907.5915066446
# RDTO: 0.2799075915066447
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 347304.0038277578
# Dinero Final Débil: $ 324809.5891710856
# Dinero Total Final: $ 672113.5929988434
# Diferencia con el Capital Inicial: $ -327886.4070011566
# RDTO: -0.32788640700115657
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 347803.52401641326
# Dinero Final Débil: $ 473531.38559223193
# Dinero Total Final: $ 821334.9096086451
# Diferencia con el Capital Inicial: $ -178665.09039135487
# RDTO: -0.17866509039135492
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 350000.0
# Dinero Final Débil: $ 748162.2603504328
# Dinero Total Final: $ 1098162.2603504327
# Diferencia con el Capital Inicial: $ 98162.26035043271
# RDTO: 0.09816226035043263
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 374074.43491816055
# Dinero Final Débil: $ 442011.8072110163
# Dinero Total Final: $ 816086.2421291769
# Diferencia con el Capital Inicial: $ -183913.75787082314
# RDTO: -0.1839137578708231
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 333473.10847766633
# Dinero Final Débil: $ 407603.8544073187
# Dinero Total Final: $ 741076.962884985
# Diferencia con el Capital Inicial: $ -258923.03711501497
# RDTO: -0.25892303711501496
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 338748.56486796786
# Dinero Final Débil: $ 867385.081305083
# Dinero Total Final: $ 1206133.6461730509
# Diferencia con el Capital Inicial: $ 206133.64617305086
# RDTO: 0.20613364617305097
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 365638.5923289838
# Dinero Final Débil: $ 856707.9743472415
# Dinero Total Final: $ 1222346.5666762253
# Diferencia con el Capital Inicial: $ 222346.56667622528
# RDTO: 0.2223465666762252
# Dinero inicial: $ 1000000
# Dinero Final Fuerte: $ 367552.99015897047
# Dinero Final Débil: $ 660941.6157517175
# Dinero Total Final: $ 1028494.6059106879
# Diferencia con el Capital Inicial: $ 28494.60591068794
# RDTO: 0.028494605910687865
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11716\1539777321.py in ?()
#       1 for i in range(60, 260, 5):
# ----> 2     Backtesting(1000000, i , df_2023)
#
# ~\AppData\Local\Temp\ipykernel_11716\2818045817.py in ?(capital_inicial, ventana_inicial, df)
#     330
#     331         # Verificar si la empresa es larga en la matriz de señales fuertes
#     332         if empresa in matriz_fuerte_largo.index:
#     333             # Calcular el rendimiento como precio final / precio inicial - 1
# --> 334             rendimiento = (datos_por_empresa[empresa].iloc[(ventana_inicial+5), 3] / datos_por_empresa[empresa].iloc[ventana_inicial, 3]) - 1
#     335         elif empresa in matriz_fuerte_corto.index:
#     336             # Calcular el rendimiento como precio inicial / precio final - 1 para cortos
#     337             rendimiento = (datos_por_empresa[empresa].iloc[ventana_inicial, 3] / datos_por_empresa[empresa].iloc[(ventana_inicial + 5), 3]) - 1
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    1142         if type(key) is tuple:
#    1143             key = tuple(list(x) if is_iterator(x) else x for x in key)
#    1144             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145             if self._is_scalar_access(key):
# -> 1146                 return self.obj._get_value(*key, takeable=self._takeable)
#    1147             return self._getitem_tuple(key)
#    1148         else:
#    1149             # we by definition only have the 0th axis
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, index, col, takeable)
#    4002         `self.columns._index_as_unique`; Caller is responsible for checking.
#    4003         """
#    4004         if takeable:
#    4005             series = self._ixs(col, axis=1)
# -> 4006             return series._values[index]
#    4007
#    4008         series = self._get_item_cache(col)
#    4009         engine = self.index._engine
#
# IndexError: index 200 is out of bounds for axis 0 with size 199

# %% [markdown]
# ### Max Drawdown

# %%
#Se extraen los rendimientos semanales por año
rdtos = pd.read_excel('Rdtos.xlsx')

# %% [markdown]
# Función que calcula el max drawdown

# %%
def calcular_max_drawdown(valores_inversion):
    # Inicializar variables
    pico_actual = 0
    valle_actual = 0
    max_drawdown = 0

    for valor_actual in valores_inversion:
        if valor_actual > pico_actual:
            pico_actual = valor_actual
            valle_actual = valor_actual
        else:
            drawdown_actual = (pico_actual - valor_actual) / pico_actual
            max_drawdown = max(drawdown_actual, max_drawdown)

    return max_drawdown

# %%
# Inicializar un DataFrame para almacenar los resultados
resultados_max_drawdown = pd.DataFrame(columns=['Año', 'Max_Drawdown'])

# Iterar sobre las columnas del DataFrame
for nombre_columna, columna in rdtos.items():
    # Aplicar dropna() a la columna y calcular el máximo drawdown
    drawdown_actual = calcular_max_drawdown(columna.dropna())

    # Almacenar el resultado en el DataFrame de resultados
    resultados_max_drawdown = pd.concat([resultados_max_drawdown, pd.DataFrame({'Año': [nombre_columna], 'Max_Drawdown': [drawdown_actual]})], ignore_index=True)

# Encontrar el máximo drawdown entre todos los años
max_drawdown_total = resultados_max_drawdown['Max_Drawdown'].max()

# Imprimir el resultado
print(f'Mayor Drawdown: {max_drawdown_total:.2%}')

# Imprimir resultados
print("Max drawdown por año:")
print(resultados_max_drawdown)
# Out:
# Mayor Drawdown: 100.08%
# Max drawdown por año:
#     Año  Max_Drawdown
# 0  2015      0.874393
# 1  2016      0.822482
# 2  2017      0.784820
# 3  2018      0.973731
# 4  2020      0.931808
# 5  2021      0.922448
# 6  2022      1.000771
# 7  2023      0.735992
# C:\Users\diwed\AppData\Local\Temp\ipykernel_28744\2524327636.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resultados_max_drawdown = pd.concat([resultados_max_drawdown, pd.DataFrame({'Año': [nombre_columna], 'Max_Drawdown': [drawdown_actual]})], ignore_index=True)

# %%
#Var y CVaR
# Nivel de confianza
confianza = 0.95

# Inicializar un DataFrame para almacenar los resultados de Var y CVaR
resultados_var_cvar = pd.DataFrame(columns=['Año', 'Var', 'CVaR'])

# Iterar sobre las columnas del DataFrame
for nombre_columna, columna in rdtos.items():
    # Calcular la Var
    var_actual = np.percentile(columna.dropna(), 100 * (1 - confianza))

    # Calcular la CVaR
    cvar_actual = columna[columna <= var_actual].mean()

    # Almacenar el resultado en el DataFrame de resultados
    resultados_var_cvar = pd.concat([resultados_var_cvar, pd.DataFrame({'Año': [nombre_columna], 'Var': [var_actual], 'CVaR': [cvar_actual]})], ignore_index=True)

# Desactivar la notación científica en pandas
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Imprimir resultados
print(resultados_var_cvar)
# Out:
#     Año        Var       CVaR
# 0  2015  215417.01  193807.10
# 1  2016  749242.46  608317.61
# 2  2017 1106722.08 1039709.76
# 3  2018  103243.34   89784.06
# 4  2020  350309.72  324811.24
# 5  2021  184594.59  153695.82
# 6  2022    -904.11   -1473.70
# 7  2023 1113095.06 1045969.99
# C:\Users\diwed\AppData\Local\Temp\ipykernel_28744\1740610376.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resultados_var_cvar = pd.concat([resultados_var_cvar, pd.DataFrame({'Año': [nombre_columna], 'Var': [var_actual], 'CVaR': [cvar_actual]})], ignore_index=True)
